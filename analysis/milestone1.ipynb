# %%
import pandas as pd

df = pd.read_csv('data/raw/listings.csv')

df.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0  21974  https://www.airbnb.com/rooms/21974  20201216161512   2020-12-17
# 1  23197  https://www.airbnb.com/rooms/23197  20201216161512   2020-12-18
# 2  32711  https://www.airbnb.com/rooms/32711  20201216161512   2020-12-18
# 3  34241  https://www.airbnb.com/rooms/34241  20201216161512   2020-12-18
# 4  34981  https://www.airbnb.com/rooms/34981  20201216161512   2020-12-17
#
#                                               name  \
# 0               Comf. double room/private bathroom
# 1  Forum DeLuxe 5 mins Walk  To CCIB Center & Sea★
# 2                 Sagrada Familia area - Còrsega 1
# 3                 Private Double room - Plaza Real
# 4             VIDRE HOME PLAZA REAL on LAS RAMBLAS
#
#                                          description  \
# 0  It is private double room with private bathroo...
# 1  Beautiful apartment, large terrace, 5 minutes ...
# ...
